# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhideenthegreat/FDSFE_MMustapha/blob/main/ClassActivities/Copy_of_FDSfE_kmeans_24Oct23_for_students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pylab as pl
import os
import json
# %pylab inline

plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <ipython-input-25-9d2dbc535df9>:12: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %% [markdown]
# # Get Kaggle dataset

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My\ Drive/
# Out:
# /content/gdrive/My Drive

# %%
ls kaggle.json
# Out:
# kaggle.json

# %%
# !chmod 600 kaggle.json

# %%
envs = json.load(open("kaggle.json", "r"))
os.environ["KAGGLE_USERNAME"] = envs['username']
os.environ["KAGGLE_KEY"] = envs['key']

# %%
# !kaggle datasets list
# Out:
# ref                                                         title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# iamsouravbanerjee/customer-shopping-trends-dataset          Customer Shopping Trends Dataset                   146KB  2023-10-05 06:45:37          17921        387  1.0
# prasad22/retail-transactions-dataset                        Retail Transactions Dataset                          1MB  2023-11-01 04:53:38            667         24  1.0
# nelgiriyewithana/billionaires-statistics-dataset            Billionaires Statistics Dataset (2023)             139KB  2023-09-29 13:39:28           9760        242  1.0
# redpen12/employees-satisfaction-analysis                    Employee Satisfaction Survey Data                  140KB  2023-11-03 08:56:49            837         27  1.0
# samyakb/student-stress-factors                              Student stress factors                              887B  2023-11-02 12:42:11            644         23  0.9411765
# victorahaji/worlds-air-quality-and-water-pollution-dataset  World's Air Quality and Water Pollution Dataset     58KB  2023-10-30 12:37:47           1480         36  0.9411765
# js1js2js3js4js5/world-trading-dataset-2000-2022             World Trading Dataset (2000-2022)                   89KB  2023-11-02 04:11:03            397         22  1.0
# zeesolver/consumer-behavior-and-shopping-habits-dataset     Consumer Behavior and Shopping Habits Dataset:     146KB  2023-10-19 13:36:26           3383         58  1.0
# anshtanwar/monthly-food-price-estimates                     Global Food Price Inflation                        254KB  2023-10-21 15:33:25           5756         95  1.0
# asaniczka/top-spotify-songs-in-73-countries-daily-updated   Top Spotify Songs in 73 Countries (Daily Updated)    5MB  2023-11-04 23:18:08           2271         69  1.0
# samira1992/student-scores-simple-dataset                    👩‍🏫 Student Scores - Simple 🗃️ Dataset              310B  2023-10-17 13:35:09           1506         62  1.0
# joebeachcapital/30000-spotify-songs                         30000 Spotify Songs                                  3MB  2023-11-01 06:06:43            989         33  1.0
# amirmahdiabbootalebi/salary-by-job-title-and-country        Salary by Job Title and Country                     37KB  2023-11-02 06:37:13            635         27  1.0
# ishmaelkiptoo/us-electric-vehicle-population-data           US Electric Vehicle Population Data                  5MB  2023-10-19 06:08:32           1046         21  1.0
# amirhoseinmousavian/renewable-energy-share                  Renewable Energy Share                             604KB  2023-11-02 19:10:08            312         36  0.9411765
# iamsouravbanerjee/heart-attack-prediction-dataset           Heart Attack Risk Prediction Dataset               519KB  2023-09-27 07:07:50           6847        130  1.0
# alejopaullier/daigt-external-dataset                        DAIGT | External Dataset                             3MB  2023-10-31 19:11:35            241         70  0.7647059
# nelgiriyewithana/credit-card-fraud-detection-dataset-2023   Credit Card Fraud Detection Dataset 2023           143MB  2023-09-18 10:00:19          10472        296  1.0
# jocelyndumlao/consumer-review-of-clothing-product           Consumer Review of Clothing Product                  4MB  2023-10-19 04:45:23           1203         33  1.0
# sujalluhar/billionaires-listed-in-forbes                    Billionaires listed in Forbes                      129KB  2023-10-21 11:51:47           1061         38  1.0

# %%
# !kaggle datasets download -d camnugent/california-housing-prices -p /content/drive/MyDrive/FDSfE_F2023
# Out:
# Downloading california-housing-prices.zip to /content/drive/MyDrive/FDSfE_F2023
#   0% 0.00/400k [00:00<?, ?B/s]
# 100% 400k/400k [00:00<00:00, 130MB/s]

# %%
# !unzip /content/drive/MyDrive/FDSfE_F2023/california-housing-prices.zip -d /content/drive/MyDrive/FDSfE_F2023
# Out:
# Archive:  /content/drive/MyDrive/FDSfE_F2023/california-housing-prices.zip
#   inflating: /content/drive/MyDrive/FDSfE_F2023/housing.csv

# %% [markdown]
# # Read dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/FDSfE_F2023/housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# # Select subset of data and scale it

# %%
X = df.loc[:, ["median_income", "latitude", "longitude"]]
X
# Out:
#        median_income  latitude  longitude
# 0             8.3252     37.88    -122.23
# 1             8.3014     37.86    -122.22
# 2             7.2574     37.85    -122.24
# 3             5.6431     37.85    -122.25
# 4             3.8462     37.85    -122.25
# ...              ...       ...        ...
# 20635         1.5603     39.48    -121.09
# 20636         2.5568     39.49    -121.21
# 20637         1.7000     39.43    -121.22
# 20638         1.8672     39.43    -121.32
# 20639         2.3886     39.37    -121.24
#
# [20640 rows x 3 columns]

# %%
X.describe()
# Out:
#        median_income      latitude     longitude
# count   20640.000000  20640.000000  20640.000000
# mean        3.870671     35.631861   -119.569704
# std         1.899822      2.135952      2.003532
# min         0.499900     32.540000   -124.350000
# 25%         2.563400     33.930000   -121.800000
# 50%         3.534800     34.260000   -118.490000
# 75%         4.743250     37.710000   -118.010000
# max        15.000100     41.950000   -114.310000

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaler.transform(X)
# Out:
# array([[ 2.34476576,  1.05254828, -1.32783522],
#        [ 2.33223796,  1.04318455, -1.32284391],
#        [ 1.7826994 ,  1.03850269, -1.33282653],
#        ...,
#        [-1.14259331,  1.77823747, -0.8237132 ],
#        [-1.05458292,  1.77823747, -0.87362627],
#        [-0.78012947,  1.75014627, -0.83369581]])

# %%
X.columns
# Out:
# Index(['median_income', 'latitude', 'longitude'], dtype='object')

# %%
X[X.columns]
# Out:
#        median_income  latitude  longitude
# 0             8.3252     37.88    -122.23
# 1             8.3014     37.86    -122.22
# 2             7.2574     37.85    -122.24
# 3             5.6431     37.85    -122.25
# 4             3.8462     37.85    -122.25
# ...              ...       ...        ...
# 20635         1.5603     39.48    -121.09
# 20636         2.5568     39.49    -121.21
# 20637         1.7000     39.43    -121.22
# 20638         1.8672     39.43    -121.32
# 20639         2.3886     39.37    -121.24
#
# [20640 rows x 3 columns]

# %%
X[X.columns] = scaler.transform(X)
X.describe()
# Out:
#        median_income      latitude     longitude
# count   2.064000e+04  2.064000e+04  2.064000e+04
# mean    6.609700e-17 -1.079584e-15 -8.526513e-15
# std     1.000024e+00  1.000024e+00  1.000024e+00
# min    -1.774299e+00 -1.447568e+00 -2.385992e+00
# 25%    -6.881186e-01 -7.967887e-01 -1.113209e+00
# 50%    -1.767951e-01 -6.422871e-01  5.389137e-01
# 75%     4.593063e-01  9.729566e-01  7.784964e-01
# max     5.858286e+00  2.958068e+00  2.625280e+00

# %% [markdown]
# # Cluster the data with kmeans

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   median_income  20640 non-null  float64
#  1   latitude       20640 non-null  float64
#  2   longitude      20640 non-null  float64
# dtypes: float64(3)
# memory usage: 483.9 KB

# %%
kmeans = KMeans(n_clusters=6)
X["Cluster"] = kmeans.fit_predict(X)
X["Cluster"] = X["Cluster"].astype("category")

X
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#        median_income  latitude  longitude Cluster
# 0           2.344766  1.052548  -1.327835       3
# 1           2.332238  1.043185  -1.322844       3
# 2           1.782699  1.038503  -1.332827       3
# 3           0.932968  1.038503  -1.337818       3
# 4          -0.012881  1.038503  -1.337818       2
# ...              ...       ...        ...     ...
# 20635      -1.216128  1.801647  -0.758826       2
# 20636      -0.691593  1.806329  -0.818722       2
# 20637      -1.142593  1.778237  -0.823713       2
# 20638      -1.054583  1.778237  -0.873626       2
# 20639      -0.780129  1.750146  -0.833696       2
#
# [20640 rows x 4 columns]

# %%
X["Cluster"].astype("category")
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        2
#         ..
# 20635    2
# 20636    2
# 20637    2
# 20638    2
# 20639    2
# Name: Cluster, Length: 20640, dtype: category
# Categories (6, int64): [0, 1, 2, 3, 4, 5]

# %% [markdown]
# # Visualize the clusters locations

# %%
sns.relplot(
    x="longitude", y="latitude", hue="Cluster", data=X, height=6,
)

# %% [markdown]
# # Visualize the cluster values

# %%
X["median_house_value"] = df["median_house_value"]
sns.catplot(x="median_house_value", y="Cluster", data=X, kind="boxen", height=6);
